# %% [markdown]
# #Q1. How can you create a Bokeh plot using Python code?

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
from bokeh.plotting import figure, output_file, show 
graph = figure(title = "Bokeh Line Graph") 
x = [1, 3, 5, 7, 9] 
y = [2, 4, 6, 8, 10] 
graph.line(x, y) 
show(graph)
# Out:
#   <div id="36db846a-edd1-43e8-8763-301250c0a5fa" data-root-id="p1002" style="display: contents;"></div>

# %% [markdown]
# #Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# Glyphs are the building blocks of Bokeh visualizations. A glyph is a vectorized graphical shape or marker that is used to represent your data. Here are a few different categories of glyphs. They can be a marker—shapes like lines,circles, diamonds, squares, and triangles.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
x1 = [1, 3, 4, 5, 6]
x2 = [5, 3, 8, 1, 8]
y1 = [6, 7, 8, 9, 4]
y2 = [3, 4, 5, 6, 7]
p = figure(title="Drawing multiple lines", x_axis_label="x-axis", y_axis_label="y-axis")
p.line(x1, y1, legend_label="line 1", line_color="red", line_width=1)
p.line(x2, y2, legend_label="line 2", line_color="blue", line_width=2)
p.line(x1, y2, legend_label="line 3", line_color="black", line_width=3)
output_notebook()
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1271">Loading BokehJS ...</span>
#     </div>
#   <div id="6fc833ad-be0f-4cfd-90cb-55cbc2eda411" data-root-id="p1139" style="display: contents;"></div>

# %% [markdown]
# #Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.plotting import figure, output_file, show
import math
x2 = list(range(1,11))
y4 = [math.pow(i,2) for i in x2]
y2 = [math.log10(pow(10,i)) for i in x2]
fig = figure(y_axis_type = 'log', title="Dual color and shape", x_axis_label="x-axis", y_axis_label="y-axis")
fig.circle(x2, y2,size = 5, color = 'blue', legend_label = 'blue circle')
fig.line(x2,y4, line_width = 2, line_color = 'red', legend_label = 'red line')
fig.legend.location = 'top_left'
fig.legend.title = 'Legend Title'
fig.legend.title_text_font = 'Arial'
fig.legend.title_text_font_size = '20pt'
fig.title_location='above'
show(fig)
# Out:
#   <div id="3b0da8a7-3cf9-46bd-8787-319efda98a8f" data-root-id="p1432" style="display: contents;"></div>

# %% [markdown]
# #Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?

# %% [markdown]
# Bokeh server makes it easy to create interactive web applications that connect front-end UI events to running Python code. Bokeh creates high-level Python models, such as plots, ranges, axes, and glyphs, and then converts these objects to JSON to pass them to its client library, BokehJS.
# A Bokeh server uses Application code written in Python to create Bokeh Documents. Every new connection from a client browser results in the Bokeh server creating a new document, just for that session.
#
# First, we have to develop an application code to be served to client browser.
# Next, start Bokeh server by following command line −
# Bokeh serve –show sliders.py
# Bokeh server starts running and serving the application at localhost:5006/sliders.
# Open your favourite browser and enter address.

# %% [markdown]
# #Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# Step 1: Setting up a basic Django project
# Step 2: Create the Django project
# Step 3:Complete Bokeh Setup into our project:
